# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Settings
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12,6)

# %%
df = pd.read_csv("vehicle_sales.csv")

# Preview
df.head()
# Out:
#          DATE  UNRATE  TOTALSA
# 0  1976-01-01     7.9   12.814
# 1  1976-02-01     7.7   13.340
# 2  1976-03-01     7.6   13.378
# 3  1976-04-01     7.7   13.223
# 4  1976-05-01     7.4   12.962

# %%
# Dataset info
df.info()

# Columns
df.columns

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     528 non-null    object
#  1   UNRATE   528 non-null    float64
#  2   TOTALSA  528 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 12.5+ KB
# DATE       0
# UNRATE     0
# TOTALSA    0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['date', 'unrate', 'totalsa']

# %%
print(list(df_brands.columns))
# Out:
# ['Nike', 'USA']

# %%
df_brands.columns = df_brands.columns.str.strip()

# %%
for col in df_brands.columns:
    print(repr(col))
# Out:
# 'Nike'
# 'USA'

# %%
import pandas as pd
import plotly.express as px

# Convert wide format to long format
df_brands_long = df_brands.melt(
    var_name="Manufacturer",
    value_name="Profit_Margin"
)

# Create box plot
fig = px.box(
    df_brands_long,
    x="Manufacturer",
    y="Profit_Margin",
    color="Manufacturer",
    title="Profit Margin Distribution"
)

fig.show()

# %%
df_brands.to_csv("ford_hyundai_kia_analysis.csv", index=False)
